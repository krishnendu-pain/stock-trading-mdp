# %% [markdown]
# #### From Dec 26, 2016 to Dec 23, 2021 -- Reliance, Airtel, Infosys, HDFC, ITC

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the datasets
rel5 = pd.read_csv("RELIANCE.NS.csv")
airt5 = pd.read_csv("BHARTIARTL.NS.csv")
inf5 = pd.read_csv("INFY.NS.csv")
hdfc5 = pd.read_csv("HDFCBANK.NS.csv")
itc5 = pd.read_csv("ITC.NS.csv")

# %%
print(rel5.shape)
print(airt5.shape)
print(inf5.shape)
print(hdfc5.shape)
print(itc5.shape)
# Out:
# (1235, 7)
# (1235, 7)
# (1235, 7)
# (1235, 7)
# (1235, 7)

# %%
rel5.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-12-26  522.224854  527.995117  517.420349  518.807251  505.524445
# 1  2016-12-27  519.005371  528.539978  518.584351  527.351257  513.849670
# 2  2016-12-28  528.936218  529.753479  518.633850  519.921692  506.610321
# 3  2016-12-29  520.070251  529.381958  519.822571  527.722717  514.211609
# 4  2016-12-30  527.400757  537.405945  526.558777  536.118164  522.392151
#
#     Volume
# 0  7070994
# 1  8049872
# 2  4447617
# 3  4048426
# 4  7251073

# %%
# Dropping unnecessary columns
rel5.drop(columns=['Open', 'Close', 'Adj Close', 'Volume'], inplace=True)
rel5.head()
# Out:
#          Date        High         Low
# 0  2016-12-26  527.995117  517.420349
# 1  2016-12-27  528.539978  518.584351
# 2  2016-12-28  529.753479  518.633850
# 3  2016-12-29  529.381958  519.822571
# 4  2016-12-30  537.405945  526.558777

# %%
airt5.drop(columns=['Open', 'Close', 'Adj Close', 'Volume'], inplace=True)
inf5.drop(columns=['Open', 'Close', 'Adj Close', 'Volume'], inplace=True)
hdfc5.drop(columns=['Open', 'Close', 'Adj Close', 'Volume'], inplace=True)
itc5.drop(columns=['Open', 'Close', 'Adj Close', 'Volume'], inplace=True)

# %%
# Taking new column Price, average of High & Low
rel5['Price'] = (rel5['High'] + rel5['Low'])/2
rel5.head()
# Out:
#          Date        High         Low       Price
# 0  2016-12-26  527.995117  517.420349  522.707733
# 1  2016-12-27  528.539978  518.584351  523.562164
# 2  2016-12-28  529.753479  518.633850  524.193665
# 3  2016-12-29  529.381958  519.822571  524.602265
# 4  2016-12-30  537.405945  526.558777  531.982361

# %%
airt5['Price'] = (airt5['High'] + airt5['Low'])/2
inf5['Price'] = (inf5['High'] + inf5['Low'])/2
hdfc5['Price'] = (hdfc5['High'] + hdfc5['Low'])/2
itc5['Price'] = (itc5['High'] + itc5['Low'])/2

# %%
rel5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1235 non-null   object
#  1   High    1235 non-null   float64
#  2   Low     1235 non-null   float64
#  3   Price   1235 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 38.7+ KB

# %%
# past 4 years' data of Reliance
rel4 = rel5[rel5['Date'] > '2017-12-26']
print(rel4.shape)
rel4.head()
# Out:
# (985, 4)
#            Date        High         Low       Price
# 250  2017-12-27  928.696899  910.370605  919.533752
# 251  2017-12-28  925.625977  910.469666  918.047822
# 252  2017-12-29  923.545715  909.875305  916.710510
# 253  2018-01-01  914.035828  898.978577  906.507202
# 254  2018-01-02  910.915405  897.888916  904.402161

# %%
# past 4 years' data of others
airt4 = airt5[airt5['Date'] > '2017-12-26']
inf4 = inf5[inf5['Date'] > '2017-12-26']
hdfc4 = hdfc5[hdfc5['Date'] > '2017-12-26']
itc4 = itc5[itc5['Date'] > '2017-12-26']

# %%
# past 3 years' data of all
rel3 = rel4[rel4['Date'] > '2018-12-26']
airt3 = airt4[airt4['Date'] > '2018-12-26']
inf3 = inf4[inf4['Date'] > '2018-12-26']
hdfc3 = hdfc4[hdfc4['Date'] > '2018-12-26']
itc3 = itc4[itc4['Date'] > '2018-12-26']

print(rel3.shape)
# Out:
# (739, 4)

# %%
# past 2 years' data of all
rel2 = rel3[rel3['Date'] > '2019-12-26']
airt2 = airt3[airt3['Date'] > '2019-12-26']
inf2 = inf3[inf3['Date'] > '2019-12-26']
hdfc2 = hdfc3[hdfc3['Date'] > '2019-12-26']
itc2 = itc3[itc3['Date'] > '2019-12-26']

print(rel2.shape)
# Out:
# (496, 4)

# %%
# past 1 year data of all
rel1 = rel2[rel2['Date'] > '2020-12-26']
airt1 = airt2[airt2['Date'] > '2020-12-26']
inf1 = inf2[inf2['Date'] > '2020-12-26']
hdfc1 = hdfc2[hdfc2['Date'] > '2020-12-26']
itc1 = itc2[itc2['Date'] > '2020-12-26']

print(rel1.shape)
# Out:
# (246, 4)

# %% [markdown]
# ## Task 1
# Generate One Step Transition Probability Matrix for depreciation/appreciation of 10%, 8%, 5%, 2% and 1%.

# %%
# Convert Price column to list
rel5_prices = rel5['Price'].tolist()
airt5_prices = airt5['Price'].tolist()
inf5_prices = inf5['Price'].tolist()
hdfc5_prices = hdfc5['Price'].tolist()
itc5_prices = itc5['Price'].tolist()

rel4_prices = rel4['Price'].tolist()
airt4_prices = airt4['Price'].tolist()
inf4_prices = inf4['Price'].tolist()
hdfc4_prices = hdfc4['Price'].tolist()
itc4_prices = itc4['Price'].tolist()

rel3_prices = rel3['Price'].tolist()
airt3_prices = airt3['Price'].tolist()
inf3_prices = inf3['Price'].tolist()
hdfc3_prices = hdfc3['Price'].tolist()
itc3_prices = itc3['Price'].tolist()

rel2_prices = rel2['Price'].tolist()
airt2_prices = airt2['Price'].tolist()
inf2_prices = inf2['Price'].tolist()
hdfc2_prices = hdfc2['Price'].tolist()
itc2_prices = itc2['Price'].tolist()

rel1_prices = rel1['Price'].tolist()
airt1_prices = airt1['Price'].tolist()
inf1_prices = inf1['Price'].tolist()
hdfc1_prices = hdfc1['Price'].tolist()
itc1_prices = itc1['Price'].tolist()

# %%
def probability_transition_matrix(prices, depreciation):
    for p in depreciation:
        prev_price = prices[0]
        last_stage = 1
        P = np.zeros([3, 3])
        TPM = np.zeros([3, 3])
        for day_price in prices[1:]:
            if (day_price - prev_price)/prev_price < -p:
                next_stage = 0
                P[last_stage, next_stage] += 1
                last_stage = 0
            elif (day_price - prev_price)/prev_price >= -p and (day_price - prev_price)/prev_price <= p:
                next_stage = 1
                P[last_stage, next_stage] += 1
                last_stage = 1
            else:
                next_stage = 2
                P[last_stage, next_stage] += 1
                last_stage = 2
            prev_price = day_price

        for i in range(0, 3):
            for j in range(0, 3):
                TPM[i, j] = P[i, j]/np.sum(P[i])
        TPM[np.isnan(TPM)] = 0

        print("For depreciation of {}%, One step transition matrix is: \n".format(p*100))
        print(P)
        print("\n")
        print("Corresponding One step transition probability matrix is :\n")
        print(TPM)
        print("\n")

# %%
# Reliance
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]

probability_transition_matrix(rel5_prices, depreciation)
# Out:
# For depreciation of 10.0%, One step transition matrix is:
#
# [[   0.    0.    0.]
#  [   0. 1230.    2.]
#  [   0.    2.    0.]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.         0.         0.        ]
#  [0.         0.99837662 0.00162338]
#  [0.         1.         0.        ]]
#
#
# For depreciation of 8.0%, One step transition matrix is:
#
# [[   0.    0.    0.]
#  [   0. 1228.    3.]
#  [   0.    3.    0.]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.         0.         0.        ]
#  [0.         0.99756296 0.00243704]
#  [0.         1.         0.        ]]
#
#
# For depreciation of 5.0%, One step transition matrix is:
#
# [[2.000e+00 5.000e+00 1.000e+00]
#  [5.000e+00 1.204e+03 8.000e+00]
#  [1.000e+00 8.000e+00 0.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.25       0.625      0.125     ]
#  [0.00410846 0.989318   0.00657354]
#  [0.11111111 0.88888889 0.        ]]
#
#
# ...

# %%
# Airtel
probability_transition_matrix(airt5_prices, depreciation)
# Out:
# For depreciation of 10.0%, One step transition matrix is:
#
# [[0.000e+00 0.000e+00 0.000e+00]
#  [0.000e+00 1.232e+03 1.000e+00]
#  [0.000e+00 1.000e+00 0.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 9.99188970e-01 8.11030008e-04]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00]]
#
#
# For depreciation of 8.0%, One step transition matrix is:
#
# [[0.000e+00 0.000e+00 1.000e+00]
#  [1.000e+00 1.225e+03 3.000e+00]
#  [0.000e+00 4.000e+00 0.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.00000000e+00 0.00000000e+00 1.00000000e+00]
#  [8.13669650e-04 9.96745321e-01 2.44100895e-03]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00]]
#
#
# For depreciation of 5.0%, One step transition matrix is:
#
# [[0.000e+00 6.000e+00 1.000e+00]
#  [6.000e+00 1.186e+03 1.600e+01]
#  [1.000e+00 1.600e+01 2.000e+00]]
#
#
# ...

# %%
# Infosys
probability_transition_matrix(inf5_prices, depreciation)
# Out:
# For depreciation of 10.0%, One step transition matrix is:
#
# [[0.00e+00 1.00e+00 0.00e+00]
#  [1.00e+00 1.23e+03 1.00e+00]
#  [0.00e+00 1.00e+00 0.00e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.00000000e+00 1.00000000e+00 0.00000000e+00]
#  [8.11688312e-04 9.98376623e-01 8.11688312e-04]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00]]
#
#
# For depreciation of 8.0%, One step transition matrix is:
#
# [[0.000e+00 1.000e+00 0.000e+00]
#  [1.000e+00 1.228e+03 2.000e+00]
#  [0.000e+00 2.000e+00 0.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.00000000e+00 1.00000000e+00 0.00000000e+00]
#  [8.12347685e-04 9.97562957e-01 1.62469537e-03]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00]]
#
#
# For depreciation of 5.0%, One step transition matrix is:
#
# [[1.000e+00 5.000e+00 0.000e+00]
#  [4.000e+00 1.211e+03 6.000e+00]
#  [1.000e+00 5.000e+00 1.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
# ...

# %%
# HDFC
probability_transition_matrix(hdfc5_prices, depreciation)
# Out:
# For depreciation of 10.0%, One step transition matrix is:
#
# [[   0.    0.    0.]
#  [   0. 1234.    0.]
#  [   0.    0.    0.]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 0.]]
#
#
# For depreciation of 8.0%, One step transition matrix is:
#
# [[   0.    0.    0.]
#  [   0. 1230.    2.]
#  [   0.    2.    0.]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.         0.         0.        ]
#  [0.         0.99837662 0.00162338]
#  [0.         1.         0.        ]]
#
#
# For depreciation of 5.0%, One step transition matrix is:
#
# [[1.000e+00 5.000e+00 0.000e+00]
#  [5.000e+00 1.206e+03 8.000e+00]
#  [0.000e+00 8.000e+00 1.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.16666667 0.83333333 0.        ]
#  [0.00410172 0.98933552 0.00656276]
#  [0.         0.88888889 0.11111111]]
#
#
# For depreciation of 2.0%, One step transition matrix is:
#
# [[  11.   32.    4.]
# ...

# %%
# ITC
probability_transition_matrix(itc5_prices, depreciation)
# Out:
# For depreciation of 10.0%, One step transition matrix is:
#
# [[0.000e+00 2.000e+00 0.000e+00]
#  [2.000e+00 1.228e+03 1.000e+00]
#  [0.000e+00 1.000e+00 0.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.00000000e+00 1.00000000e+00 0.00000000e+00]
#  [1.62469537e-03 9.97562957e-01 8.12347685e-04]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00]]
#
#
# For depreciation of 8.0%, One step transition matrix is:
#
# [[0.000e+00 4.000e+00 0.000e+00]
#  [3.000e+00 1.223e+03 2.000e+00]
#  [1.000e+00 1.000e+00 0.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# [[0.         1.         0.        ]
#  [0.002443   0.99592834 0.00162866]
#  [0.5        0.5        0.        ]]
#
#
# For depreciation of 5.0%, One step transition matrix is:
#
# [[1.000e+00 6.000e+00 0.000e+00]
#  [5.000e+00 1.212e+03 5.000e+00]
#  [1.000e+00 4.000e+00 0.000e+00]]
#
#
# Corresponding One step transition probability matrix is :
#
# ...

# %%
rel5.rename(columns = {'Price':'Reliance'}, inplace = True)
airt5.rename(columns = {'Price':'Airtel'}, inplace = True)
inf5.rename(columns = {'Price':'Infosys'}, inplace = True)
hdfc5.rename(columns = {'Price':'HDFC'}, inplace = True)
itc5.rename(columns = {'Price':'ITC'}, inplace = True)

rel4.rename(columns = {'Price':'Reliance'}, inplace = True)
airt4.rename(columns = {'Price':'Airtel'}, inplace = True)
inf4.rename(columns = {'Price':'Infosys'}, inplace = True)
hdfc4.rename(columns = {'Price':'HDFC'}, inplace = True)
itc4.rename(columns = {'Price':'ITC'}, inplace = True)

rel3.rename(columns = {'Price':'Reliance'}, inplace = True)
airt3.rename(columns = {'Price':'Airtel'}, inplace = True)
inf3.rename(columns = {'Price':'Infosys'}, inplace = True)
hdfc3.rename(columns = {'Price':'HDFC'}, inplace = True)
itc3.rename(columns = {'Price':'ITC'}, inplace = True)

rel2.rename(columns = {'Price':'Reliance'}, inplace = True)
airt2.rename(columns = {'Price':'Airtel'}, inplace = True)
inf2.rename(columns = {'Price':'Infosys'}, inplace = True)
hdfc2.rename(columns = {'Price':'HDFC'}, inplace = True)
itc2.rename(columns = {'Price':'ITC'}, inplace = True)

rel1.rename(columns = {'Price':'Reliance'}, inplace = True)
airt1.rename(columns = {'Price':'Airtel'}, inplace = True)
inf1.rename(columns = {'Price':'Infosys'}, inplace = True)
hdfc1.rename(columns = {'Price':'HDFC'}, inplace = True)
itc1.rename(columns = {'Price':'ITC'}, inplace = True)
# Out:
# C:\Users\KRISHNENDU\anaconda3\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df5 = pd.merge(rel5[['Date', 'Reliance']], airt5[['Date', 'Airtel']], how='inner', on='Date')
df5 = pd.merge(df5, inf5[['Date', 'Infosys']], how='inner', on='Date')
df5 = pd.merge(df5, hdfc5[['Date', 'HDFC']], how='inner', on='Date')
df5 = pd.merge(df5, itc5[['Date', 'ITC']], how='inner', on='Date')
df5.head()
# Out:
#          Date    Reliance      Airtel     Infosys        HDFC         ITC
# 0  2016-12-26  522.707733  268.888534  492.274994  589.049988  223.925003
# 1  2016-12-27  523.562164  271.757843  495.475006  590.200012  229.625000
# 2  2016-12-28  524.193665  275.407608  501.199997  593.987488  234.549995
# 3  2016-12-29  524.602265  276.348725  499.037506  597.349976  234.650002
# 4  2016-12-30  531.982361  278.758942  501.187500  602.987488  239.349998

# %%
df4 = pd.merge(rel4[['Date', 'Reliance']], airt4[['Date', 'Airtel']], how='inner', on='Date')
df4 = pd.merge(df4, inf4[['Date', 'Infosys']], how='inner', on='Date')
df4 = pd.merge(df4, hdfc4[['Date', 'HDFC']], how='inner', on='Date')
df4 = pd.merge(df4, itc4[['Date', 'ITC']], how='inner', on='Date')

df3 = pd.merge(rel3[['Date', 'Reliance']], airt3[['Date', 'Airtel']], how='inner', on='Date')
df3 = pd.merge(df3, inf3[['Date', 'Infosys']], how='inner', on='Date')
df3 = pd.merge(df3, hdfc3[['Date', 'HDFC']], how='inner', on='Date')
df3 = pd.merge(df3, itc3[['Date', 'ITC']], how='inner', on='Date')

df2 = pd.merge(rel2[['Date', 'Reliance']], airt2[['Date', 'Airtel']], how='inner', on='Date')
df2 = pd.merge(df2, inf2[['Date', 'Infosys']], how='inner', on='Date')
df2 = pd.merge(df2, hdfc2[['Date', 'HDFC']], how='inner', on='Date')
df2 = pd.merge(df2, itc2[['Date', 'ITC']], how='inner', on='Date')

df1 = pd.merge(rel1[['Date', 'Reliance']], airt1[['Date', 'Airtel']], how='inner', on='Date')
df1 = pd.merge(df1, inf1[['Date', 'Infosys']], how='inner', on='Date')
df1 = pd.merge(df1, hdfc1[['Date', 'HDFC']], how='inner', on='Date')
df1 = pd.merge(df1, itc1[['Date', 'ITC']], how='inner', on='Date')

# %%
df5 = df5.set_index("Date")
df4 = df4.set_index("Date")
df3 = df3.set_index("Date")
df2 = df2.set_index("Date")
df1 = df1.set_index("Date")
df1.head()
# Out:
#                Reliance      Airtel      Infosys         HDFC         ITC
# Date
# 2020-12-28  2006.650024  521.799988  1242.000000  1412.500000  209.025002
# 2020-12-29  1997.425049  520.024994  1244.724976  1427.375000  211.800003
# 2020-12-30  1991.375000  518.350006  1245.725036  1426.450012  211.525002
# 2020-12-31  1995.250000  512.375000  1248.700012  1434.525024  209.925003
# 2021-01-01  1989.500000  512.300018  1260.650024  1431.799988  211.750000

# %%
plt.style.use("fivethirtyeight")
df5.plot(subplots=True, figsize=(12, 15), title="Past 5 years' data", ylabel="Price in ₹")
# Out:
# array([<AxesSubplot:xlabel='Date', ylabel='Price in ₹'>,
#        <AxesSubplot:xlabel='Date', ylabel='Price in ₹'>,
#        <AxesSubplot:xlabel='Date', ylabel='Price in ₹'>,
#        <AxesSubplot:xlabel='Date', ylabel='Price in ₹'>,
#        <AxesSubplot:xlabel='Date', ylabel='Price in ₹'>], dtype=object)

# %% [markdown]
# ## Task 2
# Suppose, we have ₹5,00,000. On Dec 26, 2016, we will buy stocks of 5 mentioned companies (₹1,00,000 each) with that money and hold it until the day when the price is depreciated by 10% or more. Then we will sell it and again buy with the money received when the price is depreciated by 10% or more. We will do this upto Dec 23, 2021. We will try this for depreciation by 10%, 8%, 5%, 2% and 1%. We will check these for past 5, 4, 3, 2 & 1 years respectively.

# %%
def dp_trading(amount, prices, depreciation):
    final_amount_list = []
    for p in depreciation:    
        money_in_hand = amount
        prev_price = prices[0]
        no_of_stock = money_in_hand/prev_price
        money_in_hand = 0

        for day_price in prices[1:]:
            if (day_price - prev_price)/prev_price < -p:
                if no_of_stock > 0:
                    money_in_hand = no_of_stock * day_price
                    no_of_stock = 0
                else:
                    no_of_stock = money_in_hand/day_price
                    money_in_hand = 0
            else:
                pass
            prev_price = day_price

        if no_of_stock>0:
            money_in_hand = no_of_stock * day_price
        else:
            money_in_hand = money_in_hand

        final_amount_list.append(money_in_hand)
    
    return final_amount_list

# %% [markdown]
# Firstly, we will try with past 5 years' data

# %%
# Reliance
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_rel5 = dp_trading(100000, rel5_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 5 years, I have ₹{}".format(depreciation[i]*100, final_rel5[i]))
# Out:
# For depreciation of 10.0%, after 5 years, I have ₹453221.7288815201
# For depreciation of 8.0%, after 5 years, I have ₹453221.7288815201
# For depreciation of 5.0%, after 5 years, I have ₹461254.62354450976
# For depreciation of 2.0%, after 5 years, I have ₹150261.48655080484
# For depreciation of 1.0%, after 5 years, I have ₹124679.37600167678

# %%
# Airtel
final_airt5 = dp_trading(100000, airt5_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 5 years, I have ₹{}".format(depreciation[i]*100, final_airt5[i]))
# Out:
# For depreciation of 10.0%, after 5 years, I have ₹253729.67325239372
# For depreciation of 8.0%, after 5 years, I have ₹151252.26434673436
# For depreciation of 5.0%, after 5 years, I have ₹159924.96491163265
# For depreciation of 2.0%, after 5 years, I have ₹96947.46720039565
# For depreciation of 1.0%, after 5 years, I have ₹161112.7298051715

# %%
# Infosys
final_inf5 = dp_trading(100000, inf5_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 5 years, I have ₹{}".format(depreciation[i]*100, final_inf5[i]))
# Out:
# For depreciation of 10.0%, after 5 years, I have ₹135031.2293132647
# For depreciation of 8.0%, after 5 years, I have ₹135031.2293132647
# For depreciation of 5.0%, after 5 years, I have ₹490759.75468489924
# For depreciation of 2.0%, after 5 years, I have ₹183773.99261839074
# For depreciation of 1.0%, after 5 years, I have ₹143491.0088641213

# %%
# HDFC
final_hdfc5 = dp_trading(100000, hdfc5_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 5 years, I have ₹{}".format(depreciation[i]*100, final_hdfc5[i]))
# Out:
# For depreciation of 10.0%, after 5 years, I have ₹245704.9557736346
# For depreciation of 8.0%, after 5 years, I have ₹245704.9557736346
# For depreciation of 5.0%, after 5 years, I have ₹269122.6597593591
# For depreciation of 2.0%, after 5 years, I have ₹278274.2682678251
# For depreciation of 1.0%, after 5 years, I have ₹155330.93258839572

# %%
# ITC
final_itc5 = dp_trading(100000, itc5_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 5 years, I have ₹{}".format(depreciation[i]*100, final_itc5[i]))
# Out:
# For depreciation of 10.0%, after 5 years, I have ₹129999.01274820026
# For depreciation of 8.0%, after 5 years, I have ₹133549.7570252309
# For depreciation of 5.0%, after 5 years, I have ₹114449.78330356792
# For depreciation of 2.0%, after 5 years, I have ₹56865.41424359103
# For depreciation of 1.0%, after 5 years, I have ₹56427.94564784578

# %%
def plot_bar_chart(final_rel, final_airt, final_inf, final_hdfc, final_itc):
    # set width of bar
    barWidth = 0.15
    fig, ax = plt.subplots(figsize =(15, 10))

    # set height of bar
    rel_final = (round(pd.Series(final_rel) / 100000, 2)).tolist()
    airt_final = (round(pd.Series(final_airt) / 100000, 2)).tolist()
    inf_final = (round(pd.Series(final_inf) / 100000, 2)).tolist()
    hdfc_final = (round(pd.Series(final_hdfc) / 100000, 2)).tolist()
    itc_final = (round(pd.Series(final_itc) / 100000, 2)).tolist()

    # Set position of bar on X axis
    br1 = np.arange(len(rel_final))
    br2 = [x + barWidth for x in br1]
    br3 = [x + barWidth for x in br2]
    br4 = [x + barWidth for x in br3]
    br5 = [x + barWidth for x in br4]

    # Make the plot
    plt.bar(br1, rel_final, color ='r', width = barWidth, edgecolor ='grey', label ='Reliance')
    plt.bar(br2, airt_final, color ='g', width = barWidth, edgecolor ='grey', label ='Airtel')   
    plt.bar(br3, inf_final, color ='b', width = barWidth, edgecolor ='grey', label ='Infosys')
    plt.bar(br4, hdfc_final, color ='y', width = barWidth, edgecolor ='grey', label ='HDFC')
    plt.bar(br5, itc_final, color ='c', width = barWidth, edgecolor ='grey', label ='ITC')
    
    # Adding Xticks
    plt.xlabel('Depreciation percentage', fontweight ='bold', fontsize = 15)
    plt.ylabel('Final Amount (in Lakhs of ₹)', fontweight ='bold', fontsize = 15)
    plt.xticks([r + barWidth for r in range(len(rel_final))], ['10%', '8%', '5%', '2%', '1%'])
    
    for container in ax.containers:
        ax.bar_label(container)

    plt.legend()
    plt.show()

# %%
plot_bar_chart(final_rel5, final_airt5, final_inf5, final_hdfc5, final_itc5)

# %% [markdown]
# Now, we will try with past 4 years' data

# %%
# Reliance
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_rel4 = dp_trading(100000, rel4_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 4 years, I have ₹{}".format(depreciation[i]*100, final_rel4[i]))
# Out:
# For depreciation of 10.0%, after 4 years, I have ₹257633.28636358742
# For depreciation of 8.0%, after 4 years, I have ₹257633.28636358742
# For depreciation of 5.0%, after 4 years, I have ₹262199.57460432523
# For depreciation of 2.0%, after 4 years, I have ₹121234.3058499186
# For depreciation of 1.0%, after 4 years, I have ₹259119.57942558517

# %%
# Airtel
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_airt4 = dp_trading(100000, airt4_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 4 years, I have ₹{}".format(depreciation[i]*100, final_airt4[i]))
# Out:
# For depreciation of 10.0%, after 4 years, I have ₹137843.86029838634
# For depreciation of 8.0%, after 4 years, I have ₹82170.90153143588
# For depreciation of 5.0%, after 4 years, I have ₹119716.8735687661
# For depreciation of 2.0%, after 4 years, I have ₹167066.07179700045
# For depreciation of 1.0%, after 4 years, I have ₹103559.338538557

# %%
# Infosys
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_inf4 = dp_trading(100000, inf4_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 4 years, I have ₹{}".format(depreciation[i]*100, final_inf4[i]))
# Out:
# For depreciation of 10.0%, after 4 years, I have ₹128666.82332446164
# For depreciation of 8.0%, after 4 years, I have ₹128666.82332446164
# For depreciation of 5.0%, after 4 years, I have ₹441052.5962461941
# For depreciation of 2.0%, after 4 years, I have ₹173175.6769680955
# For depreciation of 1.0%, after 4 years, I have ₹265147.13768405514

# %%
# HDFC
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_hdfc4 = dp_trading(100000, hdfc4_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 4 years, I have ₹{}".format(depreciation[i]*100, final_hdfc4[i]))
# Out:
# For depreciation of 10.0%, after 4 years, I have ₹155565.70524910162
# For depreciation of 8.0%, after 4 years, I have ₹155565.70524910162
# For depreciation of 5.0%, after 4 years, I have ₹170392.396979366
# For depreciation of 2.0%, after 4 years, I have ₹172315.6610027678
# For depreciation of 1.0%, after 4 years, I have ₹112481.73328261983

# %%
# ITC
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_itc4 = dp_trading(100000, itc4_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 4 years, I have ₹{}".format(depreciation[i]*100, final_itc4[i]))
# Out:
# For depreciation of 10.0%, after 4 years, I have ₹80216.75224622406
# For depreciation of 8.0%, after 4 years, I have ₹78083.99528503802
# For depreciation of 5.0%, after 4 years, I have ₹91115.05759881165
# For depreciation of 2.0%, after 4 years, I have ₹47949.005385399716
# For depreciation of 1.0%, after 4 years, I have ₹142784.00404653844

# %%
# Bar plot
plot_bar_chart(final_rel4, final_airt4, final_inf4, final_hdfc4, final_itc4)

# %% [markdown]
# Now, with past 3 years' data

# %%
# Reliance
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_rel3 = dp_trading(100000, rel3_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_rel3[i]))
# Out:
# For depreciation of 10.0%, after 3 years, I have ₹214386.4669618426
# For depreciation of 8.0%, after 3 years, I have ₹214386.4669618426
# For depreciation of 5.0%, after 3 years, I have ₹102444.49023902201
# For depreciation of 2.0%, after 3 years, I have ₹122444.62790030305
# For depreciation of 1.0%, after 3 years, I have ₹104021.47939907663

# %%
# Airtel
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_airt3 = dp_trading(100000, airt3_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_airt3[i]))
# Out:
# For depreciation of 10.0%, after 3 years, I have ₹233039.78501151604
# For depreciation of 8.0%, after 3 years, I have ₹138918.69529507397
# For depreciation of 5.0%, after 3 years, I have ₹202394.17568779955
# For depreciation of 2.0%, after 3 years, I have ₹119370.65136817492
# For depreciation of 1.0%, after 3 years, I have ₹117047.26765386673

# %%
# Infosys
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_inf3 = dp_trading(100000, inf3_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_inf3[i]))
# Out:
# For depreciation of 10.0%, after 3 years, I have ₹101310.72219470375
# For depreciation of 8.0%, after 3 years, I have ₹101310.72219470375
# For depreciation of 5.0%, after 3 years, I have ₹347279.5542551953
# For depreciation of 2.0%, after 3 years, I have ₹138181.49136908056
# For depreciation of 1.0%, after 3 years, I have ₹132918.961663051

# %%
# HDFC
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_hdfc3 = dp_trading(100000, hdfc3_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_hdfc3[i]))
# Out:
# For depreciation of 10.0%, after 3 years, I have ₹136648.06347425774
# For depreciation of 8.0%, after 3 years, I have ₹136648.06347425774
# For depreciation of 5.0%, after 3 years, I have ₹149671.74828593395
# For depreciation of 2.0%, after 3 years, I have ₹143040.1747011539
# For depreciation of 1.0%, after 3 years, I have ₹111855.43883115344

# %%
# ITC
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_itc3 = dp_trading(100000, itc3_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_itc3[i]))
# Out:
# For depreciation of 10.0%, after 3 years, I have ₹75480.81359451587
# For depreciation of 8.0%, after 3 years, I have ₹73473.97305158841
# For depreciation of 5.0%, after 3 years, I have ₹85735.69093347595
# For depreciation of 2.0%, after 3 years, I have ₹178769.23490932013
# For depreciation of 1.0%, after 3 years, I have ₹60776.87341822675

# %%
# plot
plot_bar_chart(final_rel3, final_airt3, final_inf3, final_hdfc3, final_itc3)

# %% [markdown]
# With past 2 years' data

# %%
# Reliance
print("------------ Reliance ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_rel2 = dp_trading(100000, rel2_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_rel2[i]))

print("----------------------------------")

# Airtel
print("------------ Airtel ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_airt2 = dp_trading(100000, airt2_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_airt2[i]))

print("----------------------------------")

# Infosys
print("------------ Infosys ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_inf2 = dp_trading(100000, inf2_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_inf2[i]))

print("----------------------------------")

# HDFC
print("------------ HDFC ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_hdfc2 = dp_trading(100000, hdfc2_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_hdfc2[i]))

print("----------------------------------")

# ITC
print("------------ ITC ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_itc2 = dp_trading(100000, itc2_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_itc2[i]))
# Out:
# ------------ Reliance ------------
# For depreciation of 10.0%, after 3 years, I have ₹155923.78403786622
# For depreciation of 8.0%, after 3 years, I have ₹155923.78403786622
# For depreciation of 5.0%, after 3 years, I have ₹74508.11983734775
# For depreciation of 2.0%, after 3 years, I have ₹118899.46096420594
# For depreciation of 1.0%, after 3 years, I have ₹152946.46516447433
# ----------------------------------
# ------------ Airtel ------------
# For depreciation of 10.0%, after 3 years, I have ₹150598.7548227858
# For depreciation of 8.0%, after 3 years, I have ₹89774.29554361409
# For depreciation of 5.0%, after 3 years, I have ₹130794.45143008747
# For depreciation of 2.0%, after 3 years, I have ₹105366.61463761625
# For depreciation of 1.0%, after 3 years, I have ₹142558.5397443733
# ----------------------------------
# ------------ Infosys ------------
# For depreciation of 10.0%, after 3 years, I have ₹251549.768907283
# ...

# %%
# plot
plot_bar_chart(final_rel2, final_airt2, final_inf2, final_hdfc2, final_itc2)

# %% [markdown]
# Last 1 year data

# %%
# Reliance
print("------------ Reliance ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_rel1 = dp_trading(100000, rel1_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_rel1[i]))

print("----------------------------------")

# Airtel
print("------------ Airtel ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_airt1 = dp_trading(100000, airt1_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_airt1[i]))

print("----------------------------------")

# Infosys
print("------------ Infosys ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_inf1 = dp_trading(100000, inf1_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_inf1[i]))

print("----------------------------------")

# HDFC
print("------------ HDFC ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_hdfc1 = dp_trading(100000, hdfc1_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_hdfc1[i]))

print("----------------------------------")

# ITC
print("------------ ITC ------------")
depreciation = [0.1, 0.08, 0.05, 0.02, 0.01]
final_itc1 = dp_trading(100000, itc1_prices, depreciation)
for i in range(0, len(depreciation)):
    print("For depreciation of {}%, after 3 years, I have ₹{}".format(depreciation[i]*100, final_itc1[i]))
# Out:
# ------------ Reliance ------------
# For depreciation of 10.0%, after 3 years, I have ₹118058.7045860323
# For depreciation of 8.0%, after 3 years, I have ₹118058.7045860323
# For depreciation of 5.0%, after 3 years, I have ₹118058.7045860323
# For depreciation of 2.0%, after 3 years, I have ₹100256.32600343588
# For depreciation of 1.0%, after 3 years, I have ₹116804.16179911219
# ----------------------------------
# ------------ Airtel ------------
# For depreciation of 10.0%, after 3 years, I have ₹130749.33225180527
# For depreciation of 8.0%, after 3 years, I have ₹130749.33225180527
# For depreciation of 5.0%, after 3 years, I have ₹103497.5087044272
# For depreciation of 2.0%, after 3 years, I have ₹147255.1954923552
# For depreciation of 1.0%, after 3 years, I have ₹107403.61559214209
# ----------------------------------
# ------------ Infosys ------------
# For depreciation of 10.0%, after 3 years, I have ₹148494.36296296297
# ...

# %%
# plot
plot_bar_chart(final_rel1, final_airt1, final_inf1, final_hdfc1, final_itc1)
